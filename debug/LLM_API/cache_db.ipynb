# %%
import sys
sys.path.append("../../src")

from llm2bert.llm_api.api_with_cache import CacheDB

# %%
cache_db = CacheDB(db_path="api_cache.db")

# %%
len(cache_db.get_all())
# Out:
# 10

# %%
cache_db.get_all()
# Out:
# [{'id': 10,
#   'prompt_hash': '3ce5118348e57b4a8d57b2da157034980f44cb1d9e62f5d13fc33c99ea23992d',
# ...
